# %%
# %matplotlib inline
from collections import defaultdict
import csv

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import brewer2mpl
from pandas import Series

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl

import multipolyfit

import random
import copy

import vincent

#Some formatting of our charts

import brewer2mpl
dark2_cmap = brewer2mpl.get_map('Pastel1', 'Qualitative', 7)
dark2_colors = dark2_cmap.mpl_colors

#colorbrewer2 Dark2 qualitative color table

rcParams['figure.figsize'] = (16, 10)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
        
pd.set_option('display.width', 600)
pd.set_option('display.max_columns', 100)
import warnings
warnings.filterwarnings('ignore', message='Polyfit*')

# %%
bike_data = pd.read_csv("./data/2014-6mos-Citi Bike trip data.csv")
bike_data_test = bike_data

# %%
bike_data_test.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id    start station name  start station latitude  start station longitude  end station id         end station name  end station latitude  end station longitude  bikeid    usertype birth year  gender
# 0           949  2014-03-01 00:00:16  2014-03-01 00:16:05               317     E 6 St & Avenue B               40.724537               -73.981854             284    Greenwich Ave & 8 Ave             40.739017             -74.002638   17440  Subscriber       1942       1
# 1           533  2014-03-01 00:00:57  2014-03-01 00:09:50               457    Broadway & W 58 St               40.766953               -73.981693             441          E 52 St & 2 Ave             40.756014             -73.967416   20855  Subscriber       1960       1
# ...

# %%
test_data = pd.read_csv("./data/test.csv")
test_data.head(5)
# Out:
#    test  test2
# 0    10     11
# 1     9     12
# 2     7     13

# %%
bike_data_test['birth year'].dtypes
# Out:
# dtype('O')

# %%
bike_data_test['age'] = bike_data_test['birth year'].convert_objects(convert_numeric=True)
#bike_data_test['age'] = bike_data_test['birth year'].apply(lambda x: 2014-x)

# %%
bike_data_test.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id    start station name  start station latitude  start station longitude  end station id         end station name  end station latitude  end station longitude  bikeid    usertype birth year  gender   age
# 0           949  2014-03-01 00:00:16  2014-03-01 00:16:05               317     E 6 St & Avenue B               40.724537               -73.981854             284    Greenwich Ave & 8 Ave             40.739017             -74.002638   17440  Subscriber       1942       1  1942
# 1           533  2014-03-01 00:00:57  2014-03-01 00:09:50               457    Broadway & W 58 St               40.766953               -73.981693             441          E 52 St & 2 Ave             40.756014             -73.967416   20855  Subscriber       1960       1  1960
# ...

# %%
bike_data_test['starttime'].dtype
# Out:
# dtype('O')

# %%
bike_data_test = bike_data_test[bike_data_test['tripduration'] < 18000]

# %%
del bike_data_test['birth year']

# %%
bike_data_test = bike_data_test[bike_data_test['age'] > 1920]

# %%
bike_data_test['starttime']  = pd.to_datetime(bike_data_test['starttime'])

# %%
bike_data_test['stoptime']  = pd.to_datetime(bike_data_test['stoptime'])

# %%
#bike_data_test.to_csv('out.csv')
bike_data_test.describe()

#find highest day
#create new frame with every minute of the day, 24 hours.
# Out:
#          tripduration  start station id  start station latitude  start station longitude  end station id  end station latitude  end station longitude          bikeid          gender             age
# count  4275772.000000    4275772.000000          4275772.000000           4275772.000000  4275772.000000        4275772.000000         4275772.000000  4275772.000000  4275772.000000  4275772.000000
# mean       763.727594        446.006920               40.734658               -73.991024      445.244573             40.734329             -73.991167    18135.154405        1.231574     1976.123730
# std        677.131146        356.901694                0.019181                 0.012106      357.861876              0.019165               0.012176     2096.363942        0.422280       11.091918
# min         60.000000         72.000000               40.680342               -74.017134       72.000000             40.680342             -74.017134    14529.000000        0.000000     1921.000000
# ...

# %%
import seaborn as sns

plt.figure(figsize=(10, 10))
bike_data_test['gender'].value_counts().plot(kind='bar', alpha=.4)
