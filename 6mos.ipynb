# %%
# %matplotlib inline
from collections import defaultdict
import csv

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import brewer2mpl
from pandas import Series

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl

import multipolyfit

import random
import copy

import vincent

#Some formatting of our charts

import brewer2mpl
dark2_cmap = brewer2mpl.get_map('Pastel1', 'Qualitative', 7)
dark2_colors = dark2_cmap.mpl_colors

#colorbrewer2 Dark2 qualitative color table

rcParams['figure.figsize'] = (16, 10)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
        
pd.set_option('display.width', 600)
pd.set_option('display.max_columns', 100)
import warnings
warnings.filterwarnings('ignore', message='Polyfit*')

# %%
bike_data = pd.read_csv("./data_raw/2014-6mos-Citi Bike trip data.csv")
bike_data_test = bike_data

# %%
bike_data_test.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id    start station name  start station latitude  start station longitude  end station id         end station name  end station latitude  end station longitude  bikeid    usertype birth year  gender
# 0           949  2014-03-01 00:00:16  2014-03-01 00:16:05               317     E 6 St & Avenue B               40.724537               -73.981854             284    Greenwich Ave & 8 Ave             40.739017             -74.002638   17440  Subscriber       1942       1
# 1           533  2014-03-01 00:00:57  2014-03-01 00:09:50               457    Broadway & W 58 St               40.766953               -73.981693             441          E 52 St & 2 Ave             40.756014             -73.967416   20855  Subscriber       1960       1
# 2           122  2014-03-01 00:01:06  2014-03-01 00:03:08               146  Hudson St & Reade St               40.716250               -74.009106             276  Duane St & Greenwich St             40.717488             -74.010455   15822  Subscriber       1984       1
# 3           134  2014-03-01 00:01:14  2014-03-01 00:03:28               146  Hudson St & Reade St               40.716250               -74.009106             276  Duane St & Greenwich St             40.717488             -74.010455   17793  Subscriber       1985       1
# 4           997  2014-03-01 00:01:18  2014-03-01 00:17:55               150     E 2 St & Avenue C               40.720874               -73.980858             461          E 20 St & 2 Ave             40.735877             -73.982050   20756  Subscriber       1977       1

# %%
bike_data_test['age'] = bike_data_test['birth year'].convert_objects(convert_numeric=True)
bike_data_test['age'] = bike_data_test['age'].apply(lambda x: 2014-x)

# %%
bike_data_test = bike_data_test[bike_data_test['tripduration'] < 18000]

# %%
del bike_data_test['birth year']
del bike_data_test['bikeid']
del bike_data_test['usertype']
#del bike_data_test['start station name']
#del bike_data_test['end station name']

# %%
bike_data_test = bike_data_test[bike_data_test['age'] < 100]

# %%
bike_data_test['starttime']  = bike_data_test['starttime'].apply(lambda x: pd.to_datetime(x))

# %%
test['borough'] = test['start station name'].astype(str)

# %%
bike_data_test['stoptime']  = bike_data_test['stoptime'].apply(lambda x: pd.to_datetime(x))

# %%
test = bike_data_test[(bike_data_test['starttime'] > '2014-07-17') & (bike_data_test['starttime'] < '2014-07-18')]

# %%
test = test.reset_index()
del test['index']

# %%
a = ['Wythe Ave & Metropolitan Ave','Metropolitan Ave & Bedford Ave','S 4 St & Wythe Ave','S 3 St & Bedford Ave','Grand St & Havemeyer S','Broadway & Berry St','S 5 Pl & S 4 St','Kent Ave & S 11 St','Bedford Ave & S 9th St','Railroad Ave & Kay Ave','Old Fulton St','Front St & Washington St','Pearl St & Anchorage Pl','Columbia Heights & Cranberry St','Henry St & Poplar St','Cadman Plaza E & Red Cross Pl','York St & Jay St','Front St & Gold St','Clark St & Henry St',\
     'Clinton St & Tillary St','Cadman Plaza E & Tillary St','Concord St & Bridge St','Nassau St & Navy St','Sands St & Navy St',\
     'Atlantic Ave & Furman St','Henry St & Atlantic Ave','Clinton St & Joralemon St','Hicks St & Montague St','Jay St & Tech Pl',\
     'Cadman Plaza West & Montague St','Johnson St & Gold St','Joralemon St & Adams St','Lawrence St & Willoughby St','Duffield St & Willoughby St',\
     'Willoughby St & Fleet St','State St & Smith St','Gallatin Pl & Livingston St','Lawrence St & Willoughby St','DeKalb Ave & Hudson Ave',\
     'Bond St & Schermerhorn St','Hanover Pl & Livingston St','Fulton St & Rockwell Pl','3 Ave & Schermerhorn St','Lafayette Ave & Fort Greene Pl',\
     'Ashland Pl & Hanson Pl','Dean St & 4 Ave','Atlantic Ave & Fort Greene Pl','S Portland Ave & Hanson Pl','Macon St & Nostrand Ave','Lefferts Pl & Franklin Ave',\
     'Hancock St & Bedford Ave','Monroe St & Bedford Ave','Monroe St & Classon Ave','Fulton St & Grand Ave','Lexington Ave & Classon Ave',\
     'Fulton St & Clermont Ave','Washington Ave & Greene Ave','Lafayette Ave & Classon Ave','DeKalb Ave & Skillman St','Willoughby Ave & Walworth St',\
     'Cumberland St & Lafayette Ave','Clermont Ave & Lafayette Ave','Lafayette Ave & St James Pl','DeKalb Ave & S Portland Ave','DeKalb Ave & Vanderbilt Ave',\
     'Franklin Ave & Myrtle Ave','Emerson Pl & Myrtle Ave','Willoughby Ave & Hall St','Washington Park','Clinton Ave & Myrtle Ave','Adelphi St & Myrtle Ave',\
     'Myrtle Ave & St Edwards St','Park Ave & St Edwards St','Carlton Ave & Park Ave','Washington Ave & Park Ave','Clinton Ave & Flushing Ave','Flushing Ave & Carlton Ave']

def f(x):
    if x in a:
        return 'Brooklyn'
    else:
        return 'Manhattan'
    
test['borough'] = test['start station name'].apply(lambda x: f(x))
test.head(5)
#df[b] = df[a].apply(lambda x: do stuff with x here)
# Out:
#    tripduration            starttime             stoptime  start station id       start station name  start station latitude  start station longitude  end station id          end station name  end station latitude  end station longitude  gender  age    borough
# 0           313  2014-07-17 00:00:10  2014-07-17 00:05:23               401  Allen St & Rivington St               40.720196               -73.989978             303     Mercer St & Spring St             40.723627             -73.999496       1   48  Manhattan
# 1           254  2014-07-17 00:00:17  2014-07-17 00:04:31               475      E 16 St & Irving Pl               40.735243               -73.987586             537   Lexington Ave & E 24 St             40.740259             -73.984092       1   23  Manhattan
# 2           670  2014-07-17 00:00:25  2014-07-17 00:11:35               349  Rivington St & Ridge St               40.718502               -73.983299             151  Cleveland Pl & Spring St             40.721816             -73.997203       1   34  Manhattan
# 3           621  2014-07-17 00:00:36  2014-07-17 00:10:57               536          1 Ave & E 30 St               40.741444               -73.975361             523           W 38 St & 8 Ave             40.754666             -73.991382       2   31  Manhattan
# 4          1271  2014-07-17 00:00:38  2014-07-17 00:21:49               284    Greenwich Ave & 8 Ave               40.739017               -74.002638             499        Broadway & W 60 St             40.769155             -73.981918       2   37  Manhattan

# %%
testbk = test[test['borough'] == 'Brooklyn']

# %%
testbk.head(5)
# Out:
#     tripduration            starttime             stoptime  start station id            start station name  start station latitude  start station longitude  end station id           end station name  end station latitude  end station longitude  gender  age   borough
# 5            778  2014-07-17 00:00:39  2014-07-17 00:13:37               532               S 5 Pl & S 4 St               40.710451               -73.960876             432          E 7 St & Avenue A             40.726218             -73.983799       1   36  Brooklyn
# 24          1439  2014-07-17 00:02:58  2014-07-17 00:26:57               157       Henry St & Atlantic Ave               40.690893               -73.996123             327   Vesey Pl & River Terrace             40.715338             -74.016584       2   43  Brooklyn
# 47           504  2014-07-17 00:05:18  2014-07-17 00:13:42               391           Clark St & Henry St               40.697601               -73.993446             395  Bond St & Schermerhorn St             40.688070             -73.984106       1   28  Brooklyn
# 61           673  2014-07-17 00:07:04  2014-07-17 00:18:17              2002  Wythe Ave & Metropolitan Ave               40.716887               -73.963198             421    Clermont Ave & Park Ave             40.695734             -73.971297       1   34  Brooklyn
# 82           962  2014-07-17 00:09:34  2014-07-17 00:25:36               414       Pearl St & Anchorage Pl               40.702819               -73.987658             397   Fulton St & Clermont Ave             40.684157             -73.969223       2   39  Brooklyn

# %%
test.to_csv('dataset.csv')
