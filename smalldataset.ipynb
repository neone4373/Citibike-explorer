# %%
# %matplotlib inline
from collections import defaultdict
import csv

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import brewer2mpl
from pandas import Series

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl

import multipolyfit

import random
import copy

import vincent

#Some formatting of our charts

import brewer2mpl
dark2_cmap = brewer2mpl.get_map('Pastel1', 'Qualitative', 7)
dark2_colors = dark2_cmap.mpl_colors

#colorbrewer2 Dark2 qualitative color table

rcParams['figure.figsize'] = (16, 10)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
        
pd.set_option('display.width', 600)
pd.set_option('display.max_columns', 100)
import warnings
warnings.filterwarnings('ignore', message='Polyfit*')

# %%
bike_data = pd.read_csv("./dataset/dataset2.csv")
bike_data_test = bike_data

# %%
bike_data_test.head(3)
# Out:
#    index  tripduration            starttime             stoptime  start station id       start station name  start station latitude  start station longitude  end station id          end station name  end station latitude  end station longitude  gender  age    borough
# 0      0           313  2014-07-17 00:00:10  2014-07-17 00:05:23               401  Allen St & Rivington St               40.720196               -73.989978             303     Mercer St & Spring St             40.723627             -73.999496       1   48  Manhattan
# 1      1           254  2014-07-17 00:00:17  2014-07-17 00:04:31               475      E 16 St & Irving Pl               40.735243               -73.987586             537   Lexington Ave & E 24 St             40.740259             -73.984092       1   23  Manhattan
# ...

# %%
bike_data_test = bike_data_test[bike_data_test['tripduration'] < 3600]

# %%
bike_data_test = bike_data_test[bike_data_test['age'] < 81]

# %%
bike_data_test = bike_data_test[bike_data_test['gender'] > 0]

# %%
bike_data_test['starttime'] = bike_data_test['starttime'].apply(lambda x: pd.to_datetime(x))

# %%
bike_data_test.head(3)
# Out:
#    index  tripduration           starttime             stoptime  start station id       start station name  start station latitude  start station longitude  end station id          end station name  end station latitude  end station longitude  gender  age    borough
# 0      0           313 2014-07-17 00:00:10  2014-07-17 00:05:23               401  Allen St & Rivington St               40.720196               -73.989978             303     Mercer St & Spring St             40.723627             -73.999496       1   48  Manhattan
# 1      1           254 2014-07-17 00:00:17  2014-07-17 00:04:31               475      E 16 St & Irving Pl               40.735243               -73.987586             537   Lexington Ave & E 24 St             40.740259             -73.984092       1   23  Manhattan
# ...

# %%
    
bike_data_test['tripduration'] = bike_data_test['tripduration'].apply(lambda x: x/60)

# %%
bike_data_test.head(3)
# Out:
#    index  tripduration           starttime             stoptime  start station id       start station name  start station latitude  start station longitude  end station id          end station name  end station latitude  end station longitude  gender  age    borough
# 0      0             5 2014-07-17 00:00:10  2014-07-17 00:05:23               401  Allen St & Rivington St               40.720196               -73.989978             303     Mercer St & Spring St             40.723627             -73.999496       1   48  Manhattan
# 1      1             4 2014-07-17 00:00:17  2014-07-17 00:04:31               475      E 16 St & Irving Pl               40.735243               -73.987586             537   Lexington Ave & E 24 St             40.740259             -73.984092       1   23  Manhattan
# ...

# %%
def f(x):
    if x < .5:
        return 1
    else:
        return round(x,0)

bike_data_test['tripduration'] = bike_data_test['tripduration'].apply(lambda x: f(x))

# %%
def f(x):
    if x == 0:
        return 1
    else:
        return x


bike_data_test['tripduration'] = bike_data_test['tripduration'].apply(lambda x: f(x))

# %%
bike_data_test.head(3)
# Out:
#    index  tripduration            starttime             stoptime  start station id       start station name  start station latitude  start station longitude  end station id          end station name  end station latitude  end station longitude  gender  age    borough
# 0      0             1  2014-07-17 00:00:10  2014-07-17 00:05:23               401  Allen St & Rivington St               40.720196               -73.989978             303     Mercer St & Spring St             40.723627             -73.999496       1   48  Manhattan
# 1      1             1  2014-07-17 00:00:17  2014-07-17 00:04:31               475      E 16 St & Irving Pl               40.735243               -73.987586             537   Lexington Ave & E 24 St             40.740259             -73.984092       1   23  Manhattan
# ...

# %%
bike_data_test.to_csv('./dataset/dataset.csv')

# %%
bike_data_test['start station id'].unique()
# Out:
# array([ 401,  475,  349,  536,  284,  532,  280,  263,  380,  445,  404,
#         494,  345,  499,  160,  488,  450,  305,  529,  276,  479,  463,
#         312,  157,  496,  311,  423,  238,  268,  412,  492,  476,  229,
#         348,  477,  461,  433,  537,  128,  237,  236,  252,  462,  391,
#         498,  116,  326,  511,  320,  146,  394,  293,  512,  521,  540,
#        2002,  497,  493,  458,  351,  152,  346,  387,  300,  368,  459,
#         444,  440,  414,  151,  539,  296,  291,  473,  396,  482,  519,
#         352,   72,  507,  161,  426,  448,  403,  347,  468,  466,  168,
#         388,  455,  513,  294,  257,  315,  470,  432,  264,  441,  358,
#        2021,  329,  375,  500,  457,  446,  453,  518,  514,  332,  127,
#        3002,  402,  415,  306,  439,  509,  363,  447,  546,  417,  487,
#         485,  336,  449,  147,  369,  285,  334,  265,  523,  489,  471,
#         504,  355,  545,  362,  438,  420, 2023,  298,  297,  528,  223,
# ...
